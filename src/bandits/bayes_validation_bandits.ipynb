# %%
from core import *
import torch
import torchvision
import torch.utils.data as Data
import numpy as np
from torch.autograd import Variable
import random
import math
import itertools

from bandits import *
# Out:
# Use GPU: False

# %%
use_cuda = torch.cuda.is_available()

# hypers that do not need to be tuned
N_Steps = 4000 # in actual training, we use 600

# Load the UCI Mushroom Dataset: 8124 datapoints, each with 22 categorical
# features and one label - edible/poisonous. The features are transformed to a
# one-hot encoding. 
# The missing values (marked with ?) are treated as a different class for now.

mushroom_dataset = pd.read_csv('mushrooms.csv')
train_labels = mushroom_dataset['class']
train_labels = train_labels.replace(['p', 'e'],
                                    [POISONOUS_CONSTANT, EDIBLE_CONSTANT])
train_features = pd.get_dummies(mushroom_dataset.drop(['class'], axis=1))

train_features = torch.tensor(train_features.values, dtype=torch.float)
train_labels = torch.tensor(train_labels.values)

trainset = torch.utils.data.TensorDataset(train_features, train_labels)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=1,
                                          shuffle=True, num_workers=1)

# TODO: cannot specify the hyper for priors outside the network

LearningRate_candidates = [1e-4, 1e-3]
Epsilon_candidates = [0.1, 0.01, 0.001]

hyper_val_error_dict = {}

if __name__ == '__main__':

    # could may have more
    hyper_list = itertools.product(LearningRate_candidates, Epsilon_candidates)
    
    for LearningRate, epsilon in hyper_list:
      
      print("*"*50)
      
      print("Learning rate: {}".format(LearningRate))
      print("Epsilon: {}".format(epsilon))
      
      # Initialize network
      optimizer_constructor = torch.optim.Adam
      optimizer_params = {'lr': LearningRate, 'eps': epsilon}
      
      eg_agent = EGreedyNNAgent(epsilon=.05, 
                                optimizer_constructor=optimizer_constructor,
                                optim_params=optimizer_params)
      eg_env = Environment(eg_agent, trainloader)

      loss = []
      regret = []
        

      for i_step in range(N_Steps):

          # Training
          loss.append(eg_env.play_round())
          regret.append(eg_env.cumulative_regret)
          
          if (i_step + 1) % 100 == 0:
            print('Step {}. Regret {}'.format(i_step, eg_env.cumulative_regret))

      plt.plot(np.array(loss))
      plt.ylabel('Loss')
      plt.show()
    
      plt.plot(np.array(regret))
      plt.ylabel('Cumulative Regret')
      plt.show()
# Out:
# **************************************************
# Learning rate: 0.0001
# Epsilon: 0.1
# Step 99. Regret 400.0
# Step 199. Regret 800.0
# Step 299. Regret 1075.0
# Step 399. Regret 1270.0
# Step 499. Regret 1525.0
# Step 599. Regret 1750.0
# Step 699. Regret 1925.0
# Step 799. Regret 2055.0
# Step 899. Regret 2275.0
# Step 999. Regret 2470.0
# Step 1099. Regret 2550.0
# Step 1199. Regret 2660.0
# Step 1299. Regret 2780.0
# Step 1399. Regret 2830.0
# Step 1499. Regret 2950.0
# Step 1599. Regret 3000.0
# Step 1699. Regret 3060.0
# Step 1799. Regret 3105.0
# Step 1899. Regret 3245.0
# Step 1999. Regret 3350.0
# Step 2099. Regret 3460.0
# Step 2199. Regret 3500.0
# Step 2299. Regret 3650.0
# Step 2399. Regret 3695.0
# Step 2499. Regret 3740.0
# Step 2599. Regret 3740.0
# Step 2699. Regret 3920.0
# Step 2799. Regret 4005.0
# Step 2899. Regret 4120.0
# Step 2999. Regret 4190.0
# Step 3099. Regret 4270.0
# Step 3199. Regret 4310.0
# Step 3299. Regret 4525.0
# Step 3399. Regret 4570.0
# Step 3499. Regret 4790.0
# Step 3599. Regret 4905.0
# Step 3699. Regret 4985.0
# Step 3799. Regret 5125.0
# Step 3899. Regret 5200.0
# Step 3999. Regret 5355.0
# **************************************************
# Learning rate: 0.0001
# Epsilon: 0.01
# Step 99. Regret 690.0
# Step 199. Regret 890.0
# Step 299. Regret 1205.0
# Step 399. Regret 1480.0
# Step 499. Regret 1710.0
# Step 599. Regret 1965.0
# Step 699. Regret 2200.0
# Step 799. Regret 2315.0
# Step 899. Regret 2385.0
# Step 999. Regret 2560.0
# Step 1099. Regret 2725.0
# Step 1199. Regret 2755.0
# Step 1299. Regret 2770.0
# Step 1399. Regret 2850.0
# Step 1499. Regret 2970.0
# Step 1599. Regret 3000.0
# Step 1699. Regret 3050.0
# Step 1799. Regret 3125.0
# Step 1899. Regret 3175.0
# Step 1999. Regret 3210.0
# Step 2099. Regret 3215.0
# Step 2199. Regret 3335.0
# Step 2299. Regret 3425.0
# Step 2399. Regret 3475.0
# Step 2499. Regret 3590.0
# Step 2599. Regret 3635.0
# Step 2699. Regret 3655.0
# Step 2799. Regret 3795.0
# Step 2899. Regret 3840.0
# Step 2999. Regret 3880.0
# Step 3099. Regret 3990.0
# Step 3199. Regret 4060.0
# Step 3299. Regret 4075.0
# Step 3399. Regret 4090.0
# Step 3499. Regret 4200.0
# Step 3599. Regret 4210.0
# Step 3699. Regret 4320.0
# Step 3799. Regret 4355.0
# Step 3899. Regret 4390.0
# Step 3999. Regret 4470.0
# **************************************************
# Learning rate: 0.0001
# Epsilon: 0.001
# Step 99. Regret 270.0
# Step 199. Regret 550.0
# Step 299. Regret 730.0
# Step 399. Regret 835.0
# Step 499. Regret 860.0
# Step 599. Regret 980.0
# Step 699. Regret 1095.0
# Step 799. Regret 1140.0
# Step 899. Regret 1195.0
# Step 999. Regret 1270.0
# Step 1099. Regret 1285.0
# Step 1199. Regret 1335.0
# Step 1299. Regret 1340.0
# Step 1399. Regret 1480.0
# Step 1499. Regret 1545.0
# Step 1599. Regret 1550.0
# Step 1699. Regret 1595.0
# Step 1799. Regret 1670.0
# Step 1899. Regret 1690.0
# Step 1999. Regret 1740.0
# Step 2099. Regret 1780.0
# Step 2199. Regret 1910.0
# Step 2299. Regret 1970.0
# Step 2399. Regret 2010.0
# Step 2499. Regret 2120.0
# Step 2599. Regret 2175.0
# Step 2699. Regret 2290.0
# Step 2799. Regret 2375.0
# Step 2899. Regret 2420.0
# Step 2999. Regret 2500.0
# Step 3099. Regret 2535.0
# Step 3199. Regret 2545.0
# Step 3299. Regret 2620.0
# Step 3399. Regret 2640.0
# Step 3499. Regret 2785.0
# Step 3599. Regret 2925.0
# Step 3699. Regret 2965.0
# Step 3799. Regret 3000.0
# Step 3899. Regret 3010.0
# Step 3999. Regret 3195.0
# **************************************************
# Learning rate: 0.001
# Epsilon: 0.1
# Step 99. Regret 375.0
# Step 199. Regret 670.0
# Step 299. Regret 885.0
# Step 399. Regret 1110.0
# Step 499. Regret 1210.0
# Step 599. Regret 1255.0
# Step 699. Regret 1510.0
# Step 799. Regret 1620.0
# Step 899. Regret 1700.0
# Step 999. Regret 1810.0
# Step 1099. Regret 1955.0
# Step 1199. Regret 2075.0
# Step 1299. Regret 2255.0
# Step 1399. Regret 2255.0
# Step 1499. Regret 2365.0
# Step 1599. Regret 2400.0
# Step 1699. Regret 2555.0
# Step 1799. Regret 2635.0
# Step 1899. Regret 2780.0
# Step 1999. Regret 2900.0
# Step 2099. Regret 3015.0
# Step 2199. Regret 3125.0
# Step 2299. Regret 3165.0
# Step 2399. Regret 3200.0
# Step 2499. Regret 3310.0
# Step 2599. Regret 3450.0
# Step 2699. Regret 3570.0
# Step 2799. Regret 3675.0
# Step 2899. Regret 3710.0
# Step 2999. Regret 3755.0
# Step 3099. Regret 3840.0
# Step 3199. Regret 3845.0
# Step 3299. Regret 3880.0
# Step 3399. Regret 3955.0
# Step 3499. Regret 4000.0
# Step 3599. Regret 4020.0
# Step 3699. Regret 4135.0
# Step 3799. Regret 4275.0
# Step 3899. Regret 4390.0
# Step 3999. Regret 4530.0
# **************************************************
# Learning rate: 0.001
# Epsilon: 0.01
# Step 99. Regret 245.0
# Step 199. Regret 445.0
# Step 299. Regret 685.0
# Step 399. Regret 860.0
# Step 499. Regret 980.0
# Step 599. Regret 1030.0
# Step 699. Regret 1105.0
# Step 799. Regret 1130.0
# Step 899. Regret 1160.0
# Step 999. Regret 1225.0
# Step 1099. Regret 1380.0
# Step 1199. Regret 1465.0
# Step 1299. Regret 1540.0
# Step 1399. Regret 1625.0
# Step 1499. Regret 1685.0
# Step 1599. Regret 1815.0
# Step 1699. Regret 1830.0
# Step 1799. Regret 1885.0
# Step 1899. Regret 1930.0
# Step 1999. Regret 1990.0
# Step 2099. Regret 2035.0
# Step 2199. Regret 2145.0
# Step 2299. Regret 2335.0
# Step 2399. Regret 2555.0
# Step 2499. Regret 2630.0
# Step 2599. Regret 2715.0
# Step 2699. Regret 2850.0
# Step 2799. Regret 2925.0
# Step 2899. Regret 2965.0
# Step 2999. Regret 3010.0
# Step 3099. Regret 3195.0
# Step 3199. Regret 3275.0
# Step 3299. Regret 3380.0
# Step 3399. Regret 3565.0
# Step 3499. Regret 3615.0
# Step 3599. Regret 3660.0
# Step 3699. Regret 3785.0
# Step 3799. Regret 3930.0
# Step 3899. Regret 4005.0
# Step 3999. Regret 4045.0
# **************************************************
# Learning rate: 0.001
# Epsilon: 0.001
# Step 99. Regret 245.0
# Step 199. Regret 640.0
# Step 299. Regret 915.0
# Step 399. Regret 1045.0
# Step 499. Regret 1180.0
# Step 599. Regret 1240.0
# Step 699. Regret 1350.0
# Step 799. Regret 1355.0
# Step 899. Regret 1435.0
# Step 999. Regret 1480.0
# Step 1099. Regret 1605.0
# Step 1199. Regret 1760.0
# Step 1299. Regret 1810.0
# Step 1399. Regret 1900.0
# Step 1499. Regret 1905.0
# Step 1599. Regret 2025.0
# Step 1699. Regret 2030.0
# Step 1799. Regret 2115.0
# Step 1899. Regret 2260.0
# Step 1999. Regret 2265.0
# Step 2099. Regret 2390.0
# Step 2199. Regret 2500.0
# Step 2299. Regret 2655.0
# Step 2399. Regret 2665.0
# Step 2499. Regret 2740.0
# Step 2599. Regret 2850.0
# Step 2699. Regret 2855.0
# Step 2799. Regret 3005.0
# Step 2899. Regret 3040.0
# Step 2999. Regret 3215.0
# Step 3099. Regret 3295.0
# Step 3199. Regret 3405.0
# Step 3299. Regret 3415.0
# Step 3399. Regret 3575.0
# Step 3499. Regret 3655.0
# Step 3599. Regret 3745.0
# Step 3699. Regret 3890.0
# Step 3799. Regret 3945.0
# Step 3899. Regret 4095.0
# Step 3999. Regret 4170.0
