# %%
from core import *
import torch
import torch.utils.data as Data
import numpy as np
from torch.autograd import Variable
import random
import math
import itertools

from bandits import *
# Out:
# Use GPU: True

# %%
use_cuda = torch.cuda.is_available()

# hypers that do not need to be tuned
N_Steps = 1000 # in actual training, we use 6000

# Load the UCI Mushroom Dataset: 8124 datapoints, each with 22 categorical
# features and one label - edible/poisonous. The features are transformed to a
# one-hot encoding. 
# The missing values (marked with ?) are treated as a different class for now.

mushroom_dataset = pd.read_csv('mushrooms.csv')
train_labels = mushroom_dataset['class']
train_labels = train_labels.replace(['p', 'e'],
                                    [POISONOUS_CONSTANT, EDIBLE_CONSTANT])
train_features = pd.get_dummies(mushroom_dataset.drop(['class'], axis=1))

train_features = torch.tensor(train_features.values, dtype=torch.float)
train_labels = torch.tensor(train_labels.values)

trainset = torch.utils.data.TensorDataset(train_features, train_labels)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=1,
                                          shuffle=True, num_workers=0)

# TODO: cannot specify the hyper for priors outside the network

LearningRate_candidates = [1e-4, 1e-3]
Epsilon_candidates = [0.1, 0.01, 0.001]
mixture_PI_candidates = [0.25, 0.5, 0.75]
mixture_sigma1_candidates = [math.exp(-0), math.exp(-1), math.exp(-2)]
mixture_sigma2_candidates = [math.exp(-6), math.exp(-7), math.exp(-8)]

learning_rate = 0.001
epsilon = 0.001

hyper_val_error_dict = {}

if __name__ == '__main__':
  
    hyper_list = itertools.product(mixture_PI_candidates,
                                   mixture_sigma1_candidates,
                                   mixture_sigma2_candidates)
    
    for pi, sigma1, sigma2  in hyper_list:
      
      print("*"*50)
      
      print('PI: {}'.format(pi))
      print('Sigma1: {}'.format(sigma1))
      print('Sigma2: {}'.format(sigma2))
      
      # Initialize network
      optimizer_constructor = torch.optim.Adam
      optimizer_params = {'lr': learning_rate, 'eps': epsilon}
      prior_params = {'pi': pi, 'sigma1': sigma1, 'sigma2': sigma2}
      
      bnn_agent = BNNAgent(optimizer_constructor=optimizer_constructor,
                           optim_params=optimizer_params,
                           prior_params=prior_params)
      bnn_env = Environment(bnn_agent, trainloader)

      loss = []
      regret = []
        

      for i_step in range(N_Steps):

          # Training
          loss.append(bnn_env.play_round())
          regret.append(bnn_env.cumulative_regret)
          
          if (i_step + 1) % 100 == 0:
            print('Step {}. Regret {}'.format(i_step, bnn_env.cumulative_regret))

      plt.plot(np.array(loss))
      plt.ylabel('Loss')
      plt.show()
    
      plt.plot(np.array(regret))
      plt.ylabel('Cumulative Regret')
      plt.show()
# Out:
# **************************************************
# PI: 0.25
# Sigma1: 1.0
# Sigma2: 0.0024787521766663585
# Step 99. Regret 430.0
# Step 199. Regret 1025.0
# Step 299. Regret 1345.0
# Step 399. Regret 2125.0
# Step 499. Regret 2635.0
# Step 599. Regret 3035.0
# Step 699. Regret 3540.0
# Step 799. Regret 3885.0
# Step 899. Regret 4220.0
# Step 999. Regret 4655.0
# **************************************************
# PI: 0.25
# Sigma1: 1.0
# Sigma2: 0.0009118819655545162
# Step 99. Regret 430.0
# Step 199. Regret 1035.0
# Step 299. Regret 1545.0
# Step 399. Regret 2135.0
# Step 499. Regret 2845.0
# Step 599. Regret 3345.0
# Step 699. Regret 3850.0
# Step 799. Regret 4190.0
# Step 899. Regret 4795.0
# Step 999. Regret 5255.0
# **************************************************
# PI: 0.25
# Sigma1: 1.0
# Sigma2: 0.00033546262790251185
# Step 99. Regret 550.0
# Step 199. Regret 1090.0
# Step 299. Regret 1580.0
# Step 399. Regret 2115.0
# Step 499. Regret 2625.0
# Step 599. Regret 2955.0
# Step 699. Regret 3620.0
# Step 799. Regret 4005.0
# Step 899. Regret 4495.0
# Step 999. Regret 4845.0
# **************************************************
# PI: 0.25
# Sigma1: 0.36787944117144233
# Sigma2: 0.0024787521766663585
# Step 99. Regret 535.0
# Step 199. Regret 1255.0
# Step 299. Regret 1660.0
# Step 399. Regret 1940.0
# Step 499. Regret 2610.0
# Step 599. Regret 3305.0
# Step 699. Regret 3615.0
# Step 799. Regret 4265.0
# Step 899. Regret 4980.0
# Step 999. Regret 5430.0
# **************************************************
# PI: 0.25
# Sigma1: 0.36787944117144233
# Sigma2: 0.0009118819655545162
# Step 99. Regret 640.0
# Step 199. Regret 1195.0
# Step 299. Regret 1790.0
# Step 399. Regret 2225.0
# Step 499. Regret 2525.0
# Step 599. Regret 2955.0
# Step 699. Regret 3415.0
# Step 799. Regret 3700.0
# Step 899. Regret 4135.0
# Step 999. Regret 4505.0
# **************************************************
# PI: 0.25
# Sigma1: 0.36787944117144233
# Sigma2: 0.00033546262790251185
# Step 99. Regret 690.0
# Step 199. Regret 1350.0
# Step 299. Regret 1900.0
# Step 399. Regret 2290.0
# Step 499. Regret 2680.0
# Step 599. Regret 3115.0
# Step 699. Regret 3335.0
# Step 799. Regret 3680.0
# Step 899. Regret 4145.0
# Step 999. Regret 4550.0
# **************************************************
# PI: 0.25
# Sigma1: 0.1353352832366127
# Sigma2: 0.0024787521766663585
# Step 99. Regret 395.0
# Step 199. Regret 1025.0
# Step 299. Regret 1720.0
# Step 399. Regret 2135.0
# Step 499. Regret 2840.0
# Step 599. Regret 3260.0
# Step 699. Regret 3640.0
# Step 799. Regret 4290.0
# Step 899. Regret 4635.0
# Step 999. Regret 5160.0
# **************************************************
# PI: 0.25
# Sigma1: 0.1353352832366127
# Sigma2: 0.0009118819655545162
# Step 99. Regret 420.0
# Step 199. Regret 1130.0
# Step 299. Regret 1485.0
# Step 399. Regret 1880.0
# Step 499. Regret 2285.0
# Step 599. Regret 2710.0
# Step 699. Regret 3200.0
# Step 799. Regret 3585.0
# Step 899. Regret 3960.0
# Step 999. Regret 4450.0
# **************************************************
# PI: 0.25
# Sigma1: 0.1353352832366127
# Sigma2: 0.00033546262790251185
# Step 99. Regret 690.0
# Step 199. Regret 1420.0
# Step 299. Regret 1880.0
# Step 399. Regret 2435.0
# Step 499. Regret 2965.0
# Step 599. Regret 3295.0
# Step 699. Regret 3845.0
# Step 799. Regret 4225.0
# Step 899. Regret 4685.0
# Step 999. Regret 5175.0
# **************************************************
# PI: 0.5
# Sigma1: 1.0
# Sigma2: 0.0024787521766663585
# Step 99. Regret 270.0
# Step 199. Regret 725.0
# Step 299. Regret 1190.0
# Step 399. Regret 1720.0
# Step 499. Regret 2140.0
# Step 599. Regret 2480.0
# Step 699. Regret 3125.0
# Step 799. Regret 3730.0
# Step 899. Regret 4260.0
# Step 999. Regret 4670.0
# **************************************************
# PI: 0.5
# Sigma1: 1.0
# Sigma2: 0.0009118819655545162
# Step 99. Regret 600.0
# Step 199. Regret 1270.0
# Step 299. Regret 1815.0
# Step 399. Regret 2450.0
# Step 499. Regret 2965.0
# Step 599. Regret 3375.0
# Step 699. Regret 3975.0
# Step 799. Regret 4400.0
# Step 899. Regret 5035.0
# Step 999. Regret 5445.0
# **************************************************
# PI: 0.5
# Sigma1: 1.0
# Sigma2: 0.00033546262790251185
# Step 99. Regret 510.0
# Step 199. Regret 875.0
# Step 299. Regret 1340.0
# Step 399. Regret 1745.0
# Step 499. Regret 2405.0
# Step 599. Regret 3035.0
# Step 699. Regret 3420.0
# Step 799. Regret 3660.0
# Step 899. Regret 4175.0
# Step 999. Regret 4540.0
# **************************************************
# PI: 0.5
# Sigma1: 0.36787944117144233
# Sigma2: 0.0024787521766663585
# Step 99. Regret 545.0
# Step 199. Regret 945.0
# Step 299. Regret 1375.0
# Step 399. Regret 1970.0
# Step 499. Regret 2260.0
# Step 599. Regret 2740.0
# Step 699. Regret 3375.0
# Step 799. Regret 3865.0
# Step 899. Regret 4440.0
# Step 999. Regret 4900.0
# **************************************************
# PI: 0.5
# Sigma1: 0.36787944117144233
# Sigma2: 0.0009118819655545162
# Step 99. Regret 580.0
# Step 199. Regret 995.0
# Step 299. Regret 1400.0
# Step 399. Regret 1885.0
# Step 499. Regret 2200.0
# Step 599. Regret 2685.0
# Step 699. Regret 3160.0
# Step 799. Regret 3545.0
# Step 899. Regret 4045.0
# Step 999. Regret 4530.0
# **************************************************
# PI: 0.5
# Sigma1: 0.36787944117144233
# Sigma2: 0.00033546262790251185
# Step 99. Regret 430.0
# Step 199. Regret 965.0
# Step 299. Regret 1525.0
# Step 399. Regret 1915.0
# Step 499. Regret 2430.0
# Step 599. Regret 2850.0
# Step 699. Regret 3305.0
# Step 799. Regret 4050.0
# Step 899. Regret 4515.0
# Step 999. Regret 5020.0
# **************************************************
# PI: 0.5
# Sigma1: 0.1353352832366127
# Sigma2: 0.0024787521766663585
# Step 99. Regret 660.0
# Step 199. Regret 1075.0
# Step 299. Regret 1435.0
# Step 399. Regret 1940.0
# Step 499. Regret 2405.0
# Step 599. Regret 2890.0
# Step 699. Regret 3400.0
# Step 799. Regret 3825.0
# Step 899. Regret 4290.0
# Step 999. Regret 4745.0
# **************************************************
# PI: 0.5
# Sigma1: 0.1353352832366127
# Sigma2: 0.0009118819655545162
# Step 99. Regret 775.0
# Step 199. Regret 1510.0
# Step 299. Regret 2060.0
# Step 399. Regret 2660.0
# Step 499. Regret 3115.0
# Step 599. Regret 3475.0
# Step 699. Regret 4025.0
# Step 799. Regret 4480.0
# Step 899. Regret 4875.0
# Step 999. Regret 5475.0
# **************************************************
# PI: 0.5
# Sigma1: 0.1353352832366127
# Sigma2: 0.00033546262790251185
# Step 99. Regret 515.0
# Step 199. Regret 950.0
# Step 299. Regret 1485.0
# Step 399. Regret 1950.0
# Step 499. Regret 2510.0
# Step 599. Regret 3015.0
# Step 699. Regret 3560.0
# Step 799. Regret 3975.0
# Step 899. Regret 4390.0
# Step 999. Regret 4730.0
# **************************************************
# PI: 0.75
# Sigma1: 1.0
# Sigma2: 0.0024787521766663585
# Step 99. Regret 615.0
# Step 199. Regret 1005.0
# Step 299. Regret 1625.0
# Step 399. Regret 2175.0
# Step 499. Regret 2665.0
# Step 599. Regret 3040.0
# Step 699. Regret 3535.0
# Step 799. Regret 3940.0
# Step 899. Regret 4395.0
# Step 999. Regret 4930.0
# **************************************************
# PI: 0.75
# Sigma1: 1.0
# Sigma2: 0.0009118819655545162
# Step 99. Regret 500.0
# Step 199. Regret 1155.0
# Step 299. Regret 1675.0
# Step 399. Regret 2235.0
# Step 499. Regret 2750.0
# Step 599. Regret 3145.0
# Step 699. Regret 3560.0
# Step 799. Regret 3960.0
# Step 899. Regret 4765.0
# Step 999. Regret 5210.0
# **************************************************
# PI: 0.75
# Sigma1: 1.0
# Sigma2: 0.00033546262790251185
# Step 99. Regret 530.0
# Step 199. Regret 1055.0
# Step 299. Regret 1650.0
# Step 399. Regret 2125.0
# Step 499. Regret 2475.0
# Step 599. Regret 3070.0
# Step 699. Regret 3655.0
# Step 799. Regret 4160.0
# Step 899. Regret 4485.0
# Step 999. Regret 4865.0
# **************************************************
# PI: 0.75
# Sigma1: 0.36787944117144233
# Sigma2: 0.0024787521766663585
# Step 99. Regret 595.0
# Step 199. Regret 1210.0
# Step 299. Regret 1785.0
# Step 399. Regret 2360.0
# Step 499. Regret 2735.0
# Step 599. Regret 3260.0
# Step 699. Regret 4010.0
# Step 799. Regret 4470.0
# Step 899. Regret 4965.0
# Step 999. Regret 5400.0
# **************************************************
# PI: 0.75
# Sigma1: 0.36787944117144233
# Sigma2: 0.0009118819655545162
# Step 99. Regret 580.0
# Step 199. Regret 1085.0
# Step 299. Regret 1720.0
# Step 399. Regret 2245.0
# Step 499. Regret 2635.0
# Step 599. Regret 3050.0
# Step 699. Regret 3585.0
# Step 799. Regret 4105.0
# Step 899. Regret 4520.0
# Step 999. Regret 4950.0
# **************************************************
# PI: 0.75
# Sigma1: 0.36787944117144233
# Sigma2: 0.00033546262790251185
# Step 99. Regret 535.0
# Step 199. Regret 1065.0
# Step 299. Regret 1530.0
# Step 399. Regret 2135.0
# Step 499. Regret 2625.0
# Step 599. Regret 3035.0
# Step 699. Regret 3430.0
# Step 799. Regret 4000.0
# Step 899. Regret 4525.0
# Step 999. Regret 5090.0
# **************************************************
# PI: 0.75
# Sigma1: 0.1353352832366127
# Sigma2: 0.0024787521766663585
# Step 99. Regret 630.0
# Step 199. Regret 1255.0
# Step 299. Regret 1770.0
# Step 399. Regret 2245.0
# Step 499. Regret 2610.0
# Step 599. Regret 3240.0
# Step 699. Regret 3805.0
# Step 799. Regret 4165.0
# Step 899. Regret 4525.0
# Step 999. Regret 4900.0
# **************************************************
# PI: 0.75
# Sigma1: 0.1353352832366127
# Sigma2: 0.0009118819655545162
# Step 99. Regret 455.0
# Step 199. Regret 1055.0
# Step 299. Regret 1550.0
# Step 399. Regret 2105.0
# Step 499. Regret 2595.0
# Step 599. Regret 2900.0
# Step 699. Regret 3370.0
# Step 799. Regret 3745.0
# Step 899. Regret 4045.0
# Step 999. Regret 4355.0
# **************************************************
# PI: 0.75
# Sigma1: 0.1353352832366127
# Sigma2: 0.00033546262790251185
# Step 99. Regret 520.0
# Step 199. Regret 1285.0
# Step 299. Regret 2050.0
# Step 399. Regret 2595.0
# Step 499. Regret 2985.0
# Step 599. Regret 3365.0
# Step 699. Regret 3885.0
# Step 799. Regret 4350.0
# Step 899. Regret 4670.0
# Step 999. Regret 5180.0
