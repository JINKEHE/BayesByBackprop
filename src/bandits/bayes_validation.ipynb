# %%
from core import *
import torch
import torchvision
import torch.utils.data as Data
import numpy as np
from torch.autograd import Variable
import random
import math
import itertools

use_cuda = torch.cuda.is_available()

# hypers that do not need to be tuned
N_Epochs = 100 # in actual training, we use 600
BatchSize = 128

valid_ratio = 1/6

Download_MNIST = True

import os.path
dataset_path = os.path.join(os.path.dirname(""), 'mnist')

raw_train_set = torchvision.datasets.MNIST(
    root=dataset_path,
    train=True,
    transform=torchvision.transforms.ToTensor(),
    download=Download_MNIST
)

raw_train_size = len(raw_train_set)
valid_size = int(raw_train_size * valid_ratio)
train_size = raw_train_size - valid_size

indices = list(range(raw_train_size))
random.shuffle(indices)
valid_indices = indices[0: valid_size]
train_indices = indices[valid_size: ]

train_set = torch.utils.data.Subset(raw_train_set, train_indices)
valid_set = torch.utils.data.Subset(raw_train_set, valid_indices)

# TODO: cannot specify the hyper for priors outside the network

# need N_epochs * 4 * 2 * 3 * 3 * 3 = 100 * 4 * 54= 21600 epochs = 648000 seconds = 180 hours
N_Samples_Testing_candidates = [1,2,5,10]
LearningRate_candidates = [1e-4, 1e-3]
mixture_PI_candidates = [0.25, 0.5, 0.75]
mixture_sigma1_candidates = [math.exp(-0), math.exp(-1), math.exp(-2)]
mixture_sigma2_candidates = [math.exp(-6), math.exp(-7), math.exp(-8)]

train_loader = Data.DataLoader(dataset=train_set, batch_size=BatchSize, shuffle=True)
valid_loader = Data.DataLoader(dataset=valid_set, batch_size=BatchSize, shuffle=True)

N_Train_Batch = train_size / BatchSize

compute_accu = lambda pred, true, digits: round((pred == true).mean() * 100, digits)

hyper_val_error_dict = {}

if __name__ == '__main__':

    # could may have more
    hyper_list = itertools.product(LearningRate_candidates, N_Samples_Testing_candidates, mixture_PI_candidates, mixture_sigma1_candidates, mixture_sigma2_candidates)
    
    for LearningRate, N_Samples_Testing, pi, sigma1, sigma2 in hyper_list:
      
      print("*"*50)
      
      print("Learning rate: {}".format(LearningRate))
      print("N_Samples_Testing: {}".format(N_Samples_Testing))
      
      # Initialize network
      net = BayesianNN(
        nn_input_size=784, 
        layer_config=[400, 400, 10], 
        activation_config=[ActivationType.RELU, ActivationType.RELU, ActivationType.SOFTMAX], 
        prior_type=PriorType.MIXTURE,
        prior_params={'pi' : pi, 'sigma1' : sigma1, 'sigma2' : sigma2},
        task_type=TaskType.CLASSIFICATION
      )

      if use_cuda:
        net = net.cuda()

      optim = torch.optim.SGD(net.parameters(), lr=LearningRate)

      # Main training loop
      train_accu_lst = []
      test_accu_lst = []

      for i_ep in range(N_Epochs):

          # Training
          net.train()

          for X, Y in train_loader:
              batch_X = Variable(X.view(X.size()[0], -1))
              batch_Y = Variable(Y.view(X.size()[0]))

              if use_cuda:
                batch_X, batch_Y = batch_X.cuda(), batch_Y.cuda()

              y_pred = net(batch_X)

              # Loss and backprop
              loss, kl, _ = net.cost_function(batch_X, batch_Y, num_samples=2, num_batches = N_Train_Batch)
              optim.zero_grad()
              loss.backward()
              optim.step()

          # Evaluate on training set
          # net.eval()
          train_X = Variable(raw_train_set.train_data[train_indices].view(train_size, -1).type(torch.FloatTensor))
          train_Y = Variable(raw_train_set.train_labels[train_indices].view(train_size, -1))

          if use_cuda:
            train_X, train_Y = train_X.cuda(), train_Y.cuda()

          pred_class = net.predict_by_sampling(train_X, num_samples=N_Samples_Testing).data.cpu().numpy().argmax(axis=1)
          true_class = train_Y.data.cpu().numpy().ravel()

          train_accu = compute_accu(pred_class, true_class, 2)
          print('Epoch', i_ep, '|  Training Accuracy:', train_accu, '%')

          train_accu_lst.append(train_accu)

          # Evaluate on test set
          test_X = Variable(raw_train_set.train_data[valid_indices].view(valid_size, -1).type(torch.FloatTensor))
          test_Y = Variable(raw_train_set.train_labels[valid_indices].view(valid_size, -1))

          if use_cuda:
            test_X, test_Y = test_X.cuda(), test_Y.cuda()

          pred_class = net.predict_by_sampling(test_X, num_samples=N_Samples_Testing).data.cpu().numpy().argmax(axis=1)
          true_class = test_Y.data.cpu().numpy().ravel()

          test_accu = compute_accu(pred_class, true_class, 2)
          print('Epoch', i_ep, '|  Valid Accuracy:', test_accu, '%')

          test_accu_lst.append(test_accu)

      # to report the final test error, I will use the average of test errors of the last 10 epochs
      report_test_error_mean = np.average(test_accu_lst[-10:])
      report_test_error_std = np.std(test_accu_lst[-10:])

      # Plot
#       import matplotlib.pyplot as plt
#       plt.style.use('seaborn-paper')

#       plt.title('Classification Accuracy on MNIST')
#       plt.plot(train_accu_lst, label='Train')
#       plt.plot(test_accu_lst, label='Test')
#       plt.ylabel('Accuracy (%)')
#       plt.xlabel('Epochs')
#       plt.legend(loc='best')
#       plt.tight_layout()
#       plt.show()
      print("Final report test error: {} +- {}".format(report_test_error_mean, report_test_error_std))
      
      hyper_val_error_dict[(LearningRate, N_Samples_Testing, pi, sigma1, sigma2)] = report_test_error_mean
      for key in hyper_val_error_dict.keys():
        print("{}: {}".format(key, hyper_val_error_dict[key]))
# Out:
# **************************************************
# Learning rate: 0.0001
# N_Samples_Testing: 1
# Epoch 0 |  Training Accuracy: 85.11 %
# Epoch 0 |  Valid Accuracy: 82.65 %
# Epoch 1 |  Training Accuracy: 82.88 %
# Epoch 1 |  Valid Accuracy: 85.79 %
# Epoch 2 |  Training Accuracy: 86.42 %
# Epoch 2 |  Valid Accuracy: 86.01 %
# Epoch 3 |  Training Accuracy: 86.63 %
# Epoch 3 |  Valid Accuracy: 86.76 %
# Epoch 4 |  Training Accuracy: 88.74 %
# Epoch 4 |  Valid Accuracy: 88.13 %
# Epoch 5 |  Training Accuracy: 89.63 %
# Epoch 5 |  Valid Accuracy: 88.73 %
# Epoch 6 |  Training Accuracy: 87.92 %
# Epoch 6 |  Valid Accuracy: 87.69 %
# Epoch 7 |  Training Accuracy: 90.4 %
# Epoch 7 |  Valid Accuracy: 89.57 %
# Epoch 8 |  Training Accuracy: 88.17 %
# Epoch 8 |  Valid Accuracy: 89.15 %
# Epoch 9 |  Training Accuracy: 90.28 %
# Epoch 9 |  Valid Accuracy: 89.33 %
# Epoch 10 |  Training Accuracy: 89.15 %
# Epoch 10 |  Valid Accuracy: 87.71 %
# Epoch 11 |  Training Accuracy: 89.8 %
# Epoch 11 |  Valid Accuracy: 89.33 %
# Epoch 12 |  Training Accuracy: 88.89 %
# Epoch 12 |  Valid Accuracy: 89.2 %
# Epoch 13 |  Training Accuracy: 91.19 %
# Epoch 13 |  Valid Accuracy: 89.63 %
# Epoch 14 |  Training Accuracy: 90.19 %
# Epoch 14 |  Valid Accuracy: 88.23 %
# Epoch 15 |  Training Accuracy: 90.62 %
# Epoch 15 |  Valid Accuracy: 90.0 %
# Epoch 16 |  Training Accuracy: 90.41 %
# Epoch 16 |  Valid Accuracy: 90.72 %
# Epoch 17 |  Training Accuracy: 91.45 %
# Epoch 17 |  Valid Accuracy: 89.61 %
# Epoch 18 |  Training Accuracy: 91.51 %
# Epoch 18 |  Valid Accuracy: 90.06 %
# Epoch 19 |  Training Accuracy: 91.06 %
# Epoch 19 |  Valid Accuracy: 90.35 %
# Epoch 20 |  Training Accuracy: 91.68 %
# Epoch 20 |  Valid Accuracy: 90.38 %
# Epoch 21 |  Training Accuracy: 90.83 %
# Epoch 21 |  Valid Accuracy: 90.32 %
# Epoch 22 |  Training Accuracy: 91.11 %
# Epoch 22 |  Valid Accuracy: 90.65 %
# Epoch 23 |  Training Accuracy: 92.49 %
# Epoch 23 |  Valid Accuracy: 90.82 %
# Epoch 24 |  Training Accuracy: 91.77 %
# Epoch 24 |  Valid Accuracy: 90.55 %
# Epoch 25 |  Training Accuracy: 91.05 %
# Epoch 25 |  Valid Accuracy: 89.89 %
# Epoch 26 |  Training Accuracy: 91.64 %
# Epoch 26 |  Valid Accuracy: 91.01 %
# Epoch 27 |  Training Accuracy: 92.37 %
# Epoch 27 |  Valid Accuracy: 91.51 %
# Epoch 28 |  Training Accuracy: 92.35 %
# Epoch 28 |  Valid Accuracy: 90.95 %
# Epoch 29 |  Training Accuracy: 92.96 %
# Epoch 29 |  Valid Accuracy: 91.58 %
# Epoch 30 |  Training Accuracy: 92.41 %
# Epoch 30 |  Valid Accuracy: 90.75 %
# Epoch 31 |  Training Accuracy: 91.95 %
# Epoch 31 |  Valid Accuracy: 91.56 %
# Epoch 32 |  Training Accuracy: 93.03 %
# Epoch 32 |  Valid Accuracy: 91.8 %
# Epoch 33 |  Training Accuracy: 92.27 %
# Epoch 33 |  Valid Accuracy: 91.6 %
# Epoch 34 |  Training Accuracy: 92.67 %
# Epoch 34 |  Valid Accuracy: 92.27 %
# Epoch 35 |  Training Accuracy: 92.2 %
# Epoch 35 |  Valid Accuracy: 91.9 %
# Epoch 36 |  Training Accuracy: 92.81 %
# Epoch 36 |  Valid Accuracy: 91.61 %
# Epoch 37 |  Training Accuracy: 92.19 %
# Epoch 37 |  Valid Accuracy: 92.13 %
# Epoch 38 |  Training Accuracy: 92.81 %
# Epoch 38 |  Valid Accuracy: 91.73 %
# Epoch 39 |  Training Accuracy: 93.37 %
# Epoch 39 |  Valid Accuracy: 92.11 %
# Epoch 40 |  Training Accuracy: 91.4 %
# Epoch 40 |  Valid Accuracy: 91.82 %
# Epoch 41 |  Training Accuracy: 94.03 %
# Epoch 41 |  Valid Accuracy: 91.84 %
# Epoch 42 |  Training Accuracy: 91.96 %
# Epoch 42 |  Valid Accuracy: 93.12 %
# Epoch 43 |  Training Accuracy: 91.76 %
# Epoch 43 |  Valid Accuracy: 90.92 %
# Epoch 44 |  Training Accuracy: 94.24 %
# Epoch 44 |  Valid Accuracy: 92.37 %
# Epoch 45 |  Training Accuracy: 93.47 %
# Epoch 45 |  Valid Accuracy: 92.64 %
# Epoch 46 |  Training Accuracy: 93.48 %
# Epoch 46 |  Valid Accuracy: 91.62 %
# Epoch 47 |  Training Accuracy: 93.66 %
# Epoch 47 |  Valid Accuracy: 92.15 %
# Epoch 48 |  Training Accuracy: 93.57 %
# Epoch 48 |  Valid Accuracy: 92.48 %
# Epoch 49 |  Training Accuracy: 93.62 %
# Epoch 49 |  Valid Accuracy: 93.28 %
# Epoch 50 |  Training Accuracy: 93.21 %
# Epoch 50 |  Valid Accuracy: 92.06 %
# Epoch 51 |  Training Accuracy: 93.54 %
# Epoch 51 |  Valid Accuracy: 92.84 %
# Epoch 52 |  Training Accuracy: 94.1 %
# Epoch 52 |  Valid Accuracy: 93.25 %
# Epoch 53 |  Training Accuracy: 93.96 %
# Epoch 53 |  Valid Accuracy: 92.06 %
# Epoch 54 |  Training Accuracy: 93.57 %
# Epoch 54 |  Valid Accuracy: 92.46 %
# Epoch 55 |  Training Accuracy: 93.57 %
# Epoch 55 |  Valid Accuracy: 92.99 %
# Epoch 56 |  Training Accuracy: 93.92 %
# Epoch 56 |  Valid Accuracy: 93.06 %
# Epoch 57 |  Training Accuracy: 93.31 %
# Epoch 57 |  Valid Accuracy: 93.4 %
# Epoch 58 |  Training Accuracy: 94.44 %
# Epoch 58 |  Valid Accuracy: 92.5 %
# Epoch 59 |  Training Accuracy: 94.31 %
# Epoch 59 |  Valid Accuracy: 92.36 %
# Epoch 60 |  Training Accuracy: 94.77 %
# Epoch 60 |  Valid Accuracy: 92.18 %
# Epoch 61 |  Training Accuracy: 94.89 %
# Epoch 61 |  Valid Accuracy: 93.12 %
# Epoch 62 |  Training Accuracy: 94.18 %
# Epoch 62 |  Valid Accuracy: 92.05 %
# Epoch 63 |  Training Accuracy: 93.85 %
# Epoch 63 |  Valid Accuracy: 92.31 %
# Epoch 64 |  Training Accuracy: 94.05 %
# Epoch 64 |  Valid Accuracy: 93.91 %
# Epoch 65 |  Training Accuracy: 94.61 %
# Epoch 65 |  Valid Accuracy: 93.6 %
# Epoch 66 |  Training Accuracy: 94.86 %
# Epoch 66 |  Valid Accuracy: 93.02 %
# Epoch 67 |  Training Accuracy: 93.53 %
# Epoch 67 |  Valid Accuracy: 93.44 %
# Epoch 68 |  Training Accuracy: 93.9 %
# Epoch 68 |  Valid Accuracy: 93.28 %
# Epoch 69 |  Training Accuracy: 94.61 %
# Epoch 69 |  Valid Accuracy: 92.37 %
# Epoch 70 |  Training Accuracy: 95.1 %
# Epoch 70 |  Valid Accuracy: 93.13 %
# Epoch 71 |  Training Accuracy: 94.98 %
# Epoch 71 |  Valid Accuracy: 93.6 %
# Epoch 72 |  Training Accuracy: 93.4 %
# Epoch 72 |  Valid Accuracy: 93.7 %
# Epoch 73 |  Training Accuracy: 94.54 %
# Epoch 73 |  Valid Accuracy: 94.04 %
# Epoch 74 |  Training Accuracy: 94.68 %
# Epoch 74 |  Valid Accuracy: 93.34 %
# Epoch 75 |  Training Accuracy: 94.26 %
# Epoch 75 |  Valid Accuracy: 93.49 %
# Epoch 76 |  Training Accuracy: 94.94 %
# Epoch 76 |  Valid Accuracy: 94.0 %
# Epoch 77 |  Training Accuracy: 94.79 %
# Epoch 77 |  Valid Accuracy: 93.25 %
# Epoch 78 |  Training Accuracy: 94.95 %
# Epoch 78 |  Valid Accuracy: 93.63 %
# Epoch 79 |  Training Accuracy: 95.2 %
# Epoch 79 |  Valid Accuracy: 93.0 %
# Epoch 80 |  Training Accuracy: 94.42 %
# Epoch 80 |  Valid Accuracy: 93.19 %
# Epoch 81 |  Training Accuracy: 94.99 %
# Epoch 81 |  Valid Accuracy: 93.32 %
# Epoch 82 |  Training Accuracy: 94.81 %
# Epoch 82 |  Valid Accuracy: 93.71 %
# Epoch 83 |  Training Accuracy: 95.47 %
# Epoch 83 |  Valid Accuracy: 93.77 %
# Epoch 84 |  Training Accuracy: 94.99 %
# Epoch 84 |  Valid Accuracy: 93.32 %
# Epoch 85 |  Training Accuracy: 94.84 %
# Epoch 85 |  Valid Accuracy: 94.11 %
# Epoch 86 |  Training Accuracy: 94.46 %
# Epoch 86 |  Valid Accuracy: 94.3 %
# Epoch 87 |  Training Accuracy: 95.17 %
# Epoch 87 |  Valid Accuracy: 94.32 %
# Epoch 88 |  Training Accuracy: 95.51 %
# Epoch 88 |  Valid Accuracy: 94.02 %
# Epoch 89 |  Training Accuracy: 94.56 %
# Epoch 89 |  Valid Accuracy: 92.94 %
# Epoch 90 |  Training Accuracy: 95.5 %
# Epoch 90 |  Valid Accuracy: 93.09 %
# Epoch 91 |  Training Accuracy: 94.75 %
# Epoch 91 |  Valid Accuracy: 94.32 %
# Epoch 92 |  Training Accuracy: 95.55 %
# Epoch 92 |  Valid Accuracy: 93.15 %
# Epoch 93 |  Training Accuracy: 95.56 %
# Epoch 93 |  Valid Accuracy: 93.62 %
# Epoch 94 |  Training Accuracy: 95.35 %
# Epoch 94 |  Valid Accuracy: 93.96 %
# Epoch 95 |  Training Accuracy: 95.62 %
# Epoch 95 |  Valid Accuracy: 93.6 %
# Epoch 96 |  Training Accuracy: 95.86 %
# Epoch 96 |  Valid Accuracy: 94.74 %
# Epoch 97 |  Training Accuracy: 95.49 %
# Epoch 97 |  Valid Accuracy: 93.36 %
# Epoch 98 |  Training Accuracy: 95.64 %
# Epoch 98 |  Valid Accuracy: 93.69 %
# Epoch 99 |  Training Accuracy: 94.34 %
# Epoch 99 |  Valid Accuracy: 93.86 %
# Final report test error: 93.739 +- 0.48483914858434946
# (0.0001, 1, 0.25, 1.0, 0.0024787521766663585): 93.739
# **************************************************
# Learning rate: 0.0001
# N_Samples_Testing: 1
# Epoch 0 |  Training Accuracy: 81.15 %
# Epoch 0 |  Valid Accuracy: 82.69 %
# Epoch 1 |  Training Accuracy: 85.37 %
# Epoch 1 |  Valid Accuracy: 84.82 %
# Epoch 2 |  Training Accuracy: 87.45 %
# Epoch 2 |  Valid Accuracy: 86.8 %
# Epoch 3 |  Training Accuracy: 87.92 %
# Epoch 3 |  Valid Accuracy: 87.21 %
# Epoch 4 |  Training Accuracy: 88.0 %
# Epoch 4 |  Valid Accuracy: 87.06 %
# Epoch 5 |  Training Accuracy: 88.62 %
# Epoch 5 |  Valid Accuracy: 87.15 %
# Epoch 6 |  Training Accuracy: 88.95 %
# Epoch 6 |  Valid Accuracy: 89.06 %
# Epoch 7 |  Training Accuracy: 89.95 %
# Epoch 7 |  Valid Accuracy: 88.95 %
# Epoch 8 |  Training Accuracy: 90.21 %
# Epoch 8 |  Valid Accuracy: 89.64 %
# Epoch 9 |  Training Accuracy: 90.2 %
# Epoch 9 |  Valid Accuracy: 89.58 %
# Epoch 10 |  Training Accuracy: 89.34 %
# Epoch 10 |  Valid Accuracy: 89.62 %
# Epoch 11 |  Training Accuracy: 90.02 %
# Epoch 11 |  Valid Accuracy: 90.27 %
# Epoch 12 |  Training Accuracy: 89.51 %
# Epoch 12 |  Valid Accuracy: 89.36 %
# Epoch 13 |  Training Accuracy: 89.5 %
# Epoch 13 |  Valid Accuracy: 90.01 %
# Epoch 14 |  Training Accuracy: 91.02 %
# Epoch 14 |  Valid Accuracy: 89.65 %
# Epoch 15 |  Training Accuracy: 91.15 %
# Epoch 15 |  Valid Accuracy: 90.02 %
# Epoch 16 |  Training Accuracy: 91.62 %
# Epoch 16 |  Valid Accuracy: 88.21 %
# Epoch 17 |  Training Accuracy: 89.99 %
# Epoch 17 |  Valid Accuracy: 90.9 %
# Epoch 18 |  Training Accuracy: 91.52 %
# Epoch 18 |  Valid Accuracy: 89.79 %
# Epoch 19 |  Training Accuracy: 91.99 %
# Epoch 19 |  Valid Accuracy: 90.69 %
# Epoch 20 |  Training Accuracy: 92.06 %
# Epoch 20 |  Valid Accuracy: 90.51 %
# Epoch 21 |  Training Accuracy: 91.73 %
# Epoch 21 |  Valid Accuracy: 89.65 %
# Epoch 22 |  Training Accuracy: 92.31 %
# Epoch 22 |  Valid Accuracy: 90.82 %
# Epoch 23 |  Training Accuracy: 91.55 %
# Epoch 23 |  Valid Accuracy: 90.9 %
# Epoch 24 |  Training Accuracy: 92.63 %
# Epoch 24 |  Valid Accuracy: 90.89 %
# Epoch 25 |  Training Accuracy: 89.36 %
# Epoch 25 |  Valid Accuracy: 90.72 %
# Epoch 26 |  Training Accuracy: 92.19 %
# Epoch 26 |  Valid Accuracy: 91.36 %
# Epoch 27 |  Training Accuracy: 90.55 %
# Epoch 27 |  Valid Accuracy: 91.21 %
# Epoch 28 |  Training Accuracy: 92.71 %
# Epoch 28 |  Valid Accuracy: 91.22 %
# Epoch 29 |  Training Accuracy: 92.99 %
# Epoch 29 |  Valid Accuracy: 92.21 %
# Epoch 30 |  Training Accuracy: 92.86 %
# Epoch 30 |  Valid Accuracy: 91.74 %
# Epoch 31 |  Training Accuracy: 92.87 %
# Epoch 31 |  Valid Accuracy: 91.23 %
# Epoch 32 |  Training Accuracy: 93.44 %
# Epoch 32 |  Valid Accuracy: 90.02 %
# Epoch 33 |  Training Accuracy: 92.48 %
# Epoch 33 |  Valid Accuracy: 91.67 %
# Epoch 34 |  Training Accuracy: 93.67 %
# Epoch 34 |  Valid Accuracy: 91.69 %
# Epoch 35 |  Training Accuracy: 92.86 %
# Epoch 35 |  Valid Accuracy: 91.79 %
# Epoch 36 |  Training Accuracy: 93.27 %
# Epoch 36 |  Valid Accuracy: 92.22 %
# Epoch 37 |  Training Accuracy: 92.89 %
# Epoch 37 |  Valid Accuracy: 91.69 %
# Epoch 38 |  Training Accuracy: 93.34 %
# Epoch 38 |  Valid Accuracy: 91.84 %
# Epoch 39 |  Training Accuracy: 93.09 %
# Epoch 39 |  Valid Accuracy: 92.13 %
# Epoch 40 |  Training Accuracy: 93.42 %
# Epoch 40 |  Valid Accuracy: 92.54 %
# Epoch 41 |  Training Accuracy: 94.1 %
# Epoch 41 |  Valid Accuracy: 92.26 %
# Epoch 42 |  Training Accuracy: 93.09 %
# Epoch 42 |  Valid Accuracy: 92.59 %
# Epoch 43 |  Training Accuracy: 93.45 %
# Epoch 43 |  Valid Accuracy: 92.81 %
# Epoch 44 |  Training Accuracy: 94.25 %
# Epoch 44 |  Valid Accuracy: 91.85 %
# Epoch 45 |  Training Accuracy: 94.14 %
# Epoch 45 |  Valid Accuracy: 92.17 %
# Epoch 46 |  Training Accuracy: 93.64 %
# Epoch 46 |  Valid Accuracy: 93.32 %
# Epoch 47 |  Training Accuracy: 94.13 %
# Epoch 47 |  Valid Accuracy: 92.35 %
# Epoch 48 |  Training Accuracy: 93.97 %
# Epoch 48 |  Valid Accuracy: 93.02 %
# Epoch 49 |  Training Accuracy: 93.75 %
# Epoch 49 |  Valid Accuracy: 92.9 %
# Epoch 50 |  Training Accuracy: 93.18 %
# Epoch 50 |  Valid Accuracy: 92.44 %
# Epoch 51 |  Training Accuracy: 93.63 %
# Epoch 51 |  Valid Accuracy: 93.23 %
# Epoch 52 |  Training Accuracy: 94.74 %
# Epoch 52 |  Valid Accuracy: 92.91 %
# Epoch 53 |  Training Accuracy: 93.9 %
# Epoch 53 |  Valid Accuracy: 92.73 %
# Epoch 54 |  Training Accuracy: 93.46 %
# Epoch 54 |  Valid Accuracy: 92.96 %
# Epoch 55 |  Training Accuracy: 94.31 %
# Epoch 55 |  Valid Accuracy: 91.61 %
# Epoch 56 |  Training Accuracy: 93.75 %
# Epoch 56 |  Valid Accuracy: 93.48 %
# Epoch 57 |  Training Accuracy: 93.97 %
# Epoch 57 |  Valid Accuracy: 93.12 %
# Epoch 58 |  Training Accuracy: 93.9 %
# Epoch 58 |  Valid Accuracy: 92.18 %
# Epoch 59 |  Training Accuracy: 94.3 %
# Epoch 59 |  Valid Accuracy: 92.93 %
# Epoch 60 |  Training Accuracy: 94.16 %
# Epoch 60 |  Valid Accuracy: 93.27 %
# Epoch 61 |  Training Accuracy: 94.97 %
# Epoch 61 |  Valid Accuracy: 92.3 %
# Epoch 62 |  Training Accuracy: 94.34 %
# Epoch 62 |  Valid Accuracy: 93.55 %
# Epoch 63 |  Training Accuracy: 94.39 %
# Epoch 63 |  Valid Accuracy: 93.58 %
# Epoch 64 |  Training Accuracy: 94.66 %
# Epoch 64 |  Valid Accuracy: 93.68 %
# Epoch 65 |  Training Accuracy: 94.75 %
# Epoch 65 |  Valid Accuracy: 92.9 %
# Epoch 66 |  Training Accuracy: 94.42 %
# Epoch 66 |  Valid Accuracy: 93.88 %
